# %% [markdown]
# Use seaborn's load_dataset function to load the iris database to answer the following questions:

# %%
# pandas for tabular data manipulation
import pandas as pd

# numpy for vectorized matrix operations
import numpy as np

# matplotlib.pyplot for basic matplotlib functionality
import matplotlib.pyplot as plt

# seabon for more visualizations! 
import seaborn as sns

# %%
from pydataset import data

# %%
# Load iris dataset
iris = data('iris')
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 1             5.1          3.5           1.4          0.2      setosa
# 2             4.9          3.0           1.4          0.2      setosa
# 3             4.7          3.2           1.3          0.2      setosa
# 4             4.6          3.1           1.5          0.2      setosa
# 5             5.0          3.6           1.4          0.2      setosa
# 6             5.4          3.9           1.7          0.4      setosa
# 7             4.6          3.4           1.4          0.3      setosa
# 8             5.0          3.4           1.5          0.2      setosa
# 9             4.4          2.9           1.4          0.2      setosa
# 10            4.9          3.1           1.5          0.1      setosa
# 11            5.4          3.7           1.5          0.2      setosa
# 12            4.8          3.4           1.6          0.2      setosa
# ...

# %% [markdown]
# What does the distribution of petal lengths look like?

# %%
sns.histplot(data=iris, x='Petal.Length')
plt.show()

# %% [markdown]
# Is there a relationship between petal length and petal width?

# %%
sns.scatterplot(data=iris, x='Petal.Length', y='Petal.Width')
plt.show()

# %% [markdown]
# Would it be reasonable to predict species based on sepal width and sepal length? For this, you'll visualize two numeric columns through the lense of a categorical column.

# %%
sns.scatterplot(data=iris, y='Sepal.Length', x='Sepal.Width', hue='Species')
plt.show()

# %% [markdown]
# Which features would be best used to predict species?

# %%
sns.pairplot (data=iris, corner=True, hue='Species')
plt.show()

#petal width and petal length are the best predictor

# %% [markdown]
# Load the anscombe dataset from seaborn.

# %%
# Load anscombe dataset
anscombe = sns.load_dataset('anscombe')

# %% [markdown]
# Use pandas to group the data by the dataset column, and calculate summary statistics for each dataset. What do you notice?

# %%
# Group data by dataset column and calculate summary statistics
grouped = anscombe.groupby('dataset').describe()
grouped
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %% [markdown]
# Plot the x and y values from the anscombe data. Each dataset should be in a separate column.

# %%
sns.relplot(data=anscombe, x='x', y='y', col='dataset')
plt.show()

# %% [markdown]
# or

# %%
# Plot x and y values for each dataset
fig, axs = plt.subplots(1, 4, figsize=(12, 4), sharex=True, sharey=True)

for i, (dataset, group) in enumerate(anscombe.groupby('dataset')):
    ax = axs[i]
    ax.scatter(x=group['x'], y=group['y'])
    ax.set_title(f"Dataset {dataset}")
    
plt.show()

# %% [markdown]
# Load the InsectSprays dataset from pydataset and read it's documentation. Create a boxplot that shows the effectiveness of the different insect sprays.

# %%
# Load InsectSprays dataset and read its documentation
data('InsectSprays', show_doc=True)
# Out:
# InsectSprays
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Effectiveness of Insect Sprays
#
# ### Description
#
# The counts of insects in agricultural experimental units treated with
# different insecticides.
#
# ### Usage
#
#     InsectSprays
#
# ### Format
#
# A data frame with 72 observations on 2 variables.
#
# [,1]
#
# count
#
# numeric
#
# Insect count
#
# [,2]
#
# spray
#
# factor
#
# The type of spray
#
# ### Source
#
# Beall, G., (1942) The Transformation of data from entomological field
# experiments, _Biometrika_, **29**, 243–262.
#
# ### References
#
# McNeil, D. (1977) _Interactive Data Analysis_. New York: Wiley.
#
# ### Examples
#
#     require(stats); require(graphics)
#     boxplot(count ~ spray, data = InsectSprays,
#             xlab = "Type of spray", ylab = "Insect count",
#             main = "InsectSprays data", varwidth = TRUE, col = "lightgray")
#     fm1 <- aov(count ~ spray, data = InsectSprays)
# ...

# %%
insect = data('InsectSprays')
insect
# Out:
#     count spray
# 1      10     A
# 2       7     A
# 3      20     A
# 4      14     A
# 5      14     A
# 6      12     A
# 7      10     A
# 8      23     A
# 9      17     A
# 10     20     A
# 11     14     A
# 12     13     A
# 13     11     B
# 14     17     B
# 15     21     B
# 16     11     B
# 17     16     B
# 18     14     B
# 19     17     B
# 20     17     B
# 21     19     B
# 22     21     B
# 23      7     B
# 24     13     B
# 25      0     C
# 26      1     C
# 27      7     C
# 28      2     C
# 29      3     C
# 30      1     C
# 31      2     C
# 32      1     C
# 33      3     C
# 34      0     C
# 35      1     C
# 36      4     C
# 37      3     D
# 38      5     D
# 39     12     D
# 40      6     D
# 41      4     D
# 42      3     D
# 43      5     D
# 44      5     D
# 45      5     D
# 46      5     D
# 47      2     D
# 48      4     D
# 49      3     E
# 50      5     E
# 51      3     E
# 52      5     E
# 53      3     E
# 54      6     E
# ...

# %%
insect.value_counts()
# Out:
# count  spray
# 5      D        5
# 3      E        4
# 1      C        4
# 17     B        3
# 14     A        3
# 0      C        2
# 6      E        2
# 21     B        2
# 20     A        2
# 15     F        2
# 13     F        2
# 11     B        2
# 10     A        2
# 26     F        2
# 3      D        2
# 1      E        2
# 2      C        2
# 4      D        2
# 5      E        2
# 3      C        2
# 14     B        1
# 24     F        1
# 23     A        1
# 22     F        1
# 19     B        1
# 2      D        1
# 17     A        1
# 16     F        1
#        B        1
# 2      E        1
# 6      D        1
# 13     B        1
#        A        1
# 12     D        1
#        A        1
# 11     F        1
# 4      C        1
#        E        1
# 9      F        1
# 7      C        1
#        B        1
#        A        1
# 10     F        1
# dtype: int64

# %%
# Create boxplot of effectiveness of different insect sprays
sns.boxplot(data=data('InsectSprays'), x='spray', y='count')
plt.show()

# %% [markdown]
# Load the swiss dataset from pydataset and read it's documentation. Create visualizations to answer the following questions:

# %%
# Load swiss dataset and read its documentation
data('swiss', show_doc=True)
# Out:
# swiss
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Swiss Fertility and Socioeconomic Indicators (1888) Data
#
# ### Description
#
# Standardized fertility measure and socio-economic indicators for each of 47
# French-speaking provinces of Switzerland at about 1888.
#
# ### Usage
#
#     data(swiss)
#
# ### Format
#
# A data frame with 47 observations on 6 variables, each of which is in percent,
# i.e., in [0,100].
#
# [,1] Fertility Ig, "common standardized fertility measure" [,2] Agriculture
# [,3] Examination nation [,4] Education [,5] Catholic [,6] Infant.Mortality
# live births who live less than 1 year.
#
# All variables but 'Fert' give proportions of the population.
#
# ### Source
#
# Project "16P5", pages 549-551 in
#
# Mosteller, F. and Tukey, J. W. (1977) “Data Analysis and Regression: A Second
# Course in Statistics”. Addison-Wesley, Reading Mass.
#
# ...

# %%
swiss_df = data('swiss')
swiss_df
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
# Porrentruy         76.1         35.3            9          7     90.57
# Broye              83.8         70.2           16          7     92.85
# Glane              92.4         67.8           14          8     97.16
# Gruyere            82.4         53.3           12          7     97.67
# Sarine             82.9         45.2           16         13     91.38
# Veveyse            87.1         64.5           14          6     98.61
# Aigle              64.1         62.0           21         12      8.52
# ...

# %% [markdown]
# Create an attribute named is_catholic that holds a boolean value of whether or not the province is Catholic. (Choose a cutoff point for what constitutes catholic)

# %%
swiss_df['is_catholic'] = swiss_df['Catholic'] > 50
swiss_df
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
# Porrentruy         76.1         35.3            9          7     90.57
# Broye              83.8         70.2           16          7     92.85
# Glane              92.4         67.8           14          8     97.16
# Gruyere            82.4         53.3           12          7     97.67
# Sarine             82.9         45.2           16         13     91.38
# Veveyse            87.1         64.5           14          6     98.61
# Aigle              64.1         62.0           21         12      8.52
# ...

# %% [markdown]
# Does whether or not a province is Catholic influence fertility?

# %%
# Create a plot to show the number of Catholic and non-Catholic provinces
sns.boxplot(data=swiss_df, x='is_catholic', y='Fertility')
plt.show()

# %% [markdown]
# What measure correlates most strongly with fertility?

# %%
# Create a heatmap to show the correlation between all the variables in the swiss dataset
sns.heatmap(data=swiss_df.corr(), cmap='Blues', annot=True)
plt.show()

# %%
for col in swiss_df:
    print(col)
    sns.scatterplot(data=swiss_df, y='Fertility', x=col)
    plt.show()
# Out:
# Fertility
# Agriculture
# Examination
# Education
# Catholic
# Infant.Mortality
# is_catholic

# %% [markdown]
# Load the chipotle dataset from SQL, create a bar chart that shows the 4 most popular items and the revenue produced by each.

# %%
from env import host_name, user, password

# %%
def get_db_url(database):
    url = f'mysql+pymysql://{user}:{password}@{host_name}/{database}'
    return url

# %%
url = get_db_url('chipotle')

# %%
orders = pd.read_sql('SELECT quantity, item_name, item_price FROM orders', url)
orders
# Out:
#       quantity                              item_name item_price
# 0            1           Chips and Fresh Tomato Salsa     $2.39
# 1            1                                   Izze     $3.39
# 2            1                       Nantucket Nectar     $3.39
# 3            1  Chips and Tomatillo-Green Chili Salsa     $2.39
# 4            2                           Chicken Bowl    $16.98
# ...        ...                                    ...        ...
# 4617         1                          Steak Burrito    $11.75
# 4618         1                          Steak Burrito    $11.75
# 4619         1                     Chicken Salad Bowl    $11.25
# 4620         1                     Chicken Salad Bowl     $8.75
# 4621         1                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 3 columns]

# %%
orders['item_price'] = orders['item_price'].str.replace('$', '', regex=False)
orders
# Out:
#       quantity                              item_name item_price
# 0            1           Chips and Fresh Tomato Salsa      2.39
# 1            1                                   Izze      3.39
# 2            1                       Nantucket Nectar      3.39
# 3            1  Chips and Tomatillo-Green Chili Salsa      2.39
# 4            2                           Chicken Bowl     16.98
# ...        ...                                    ...        ...
# 4617         1                          Steak Burrito     11.75
# 4618         1                          Steak Burrito     11.75
# 4619         1                     Chicken Salad Bowl     11.25
# 4620         1                     Chicken Salad Bowl      8.75
# 4621         1                     Chicken Salad Bowl      8.75
#
# [4622 rows x 3 columns]

# %%
# group the data by item name and calculate the revenue for each item
orders.item_price = orders.item_price.astype(str).str.replace('\$', '', regex=True).astype(float)
orders
# Out:
#       quantity                              item_name  item_price
# 0            1           Chips and Fresh Tomato Salsa        2.39
# 1            1                                   Izze        3.39
# 2            1                       Nantucket Nectar        3.39
# 3            1  Chips and Tomatillo-Green Chili Salsa        2.39
# 4            2                           Chicken Bowl       16.98
# ...        ...                                    ...         ...
# 4617         1                          Steak Burrito       11.75
# 4618         1                          Steak Burrito       11.75
# 4619         1                     Chicken Salad Bowl       11.25
# 4620         1                     Chicken Salad Bowl        8.75
# 4621         1                     Chicken Salad Bowl        8.75
#
# [4622 rows x 3 columns]

# %%
# Get the data for the revenue generated by the top 4 items
revenue_generated = orders.groupby('item_name')['item_price'].sum().sort_values(ascending=False)
revenue_generated
# Out:
# item_name
# Chicken Bowl                             7342.73
# Chicken Burrito                          5575.82
# Steak Burrito                            3851.43
# Steak Bowl                               2260.19
# Chips and Guacamole                      2201.04
# Chicken Salad Bowl                       1228.75
# Chicken Soft Tacos                       1108.09
# Veggie Burrito                            934.77
# Barbacoa Burrito                          894.75
# Veggie Bowl                               867.99
# Carnitas Bowl                             736.71
# Barbacoa Bowl                             672.36
# Carnitas Burrito                          597.83
# Steak Soft Tacos                          536.05
# Chips                                     494.34
# Chicken Crispy Tacos                      472.13
# Canned Soft Drink                         438.75
# Carnitas Soft Tacos                       375.94
# Chips and Fresh Tomato Salsa              361.36
# ...

# %%
# sort the items by revenue in descending order and select the top 4 items
pop_items = orders.groupby('item_name')['quantity'].sum().sort_values(ascending=False).head(4)
pop_items
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Name: quantity, dtype: int64

# %%
# Get the data for the revenue generated by the top 4 items
revenue_generated = orders.groupby('item_name')['item_price'].sum().sort_values(ascending=False)

# Get the data for the top 4 most popular items by quantity sold
pop_items = orders.groupby('item_name')['quantity'].sum().sort_values(ascending=False).head(4)

# Merge the two dataframes
merged_items = pd.merge(pop_items, revenue_generated, on='item_name')

# Set the plot title and axis labels
sns.barplot(y=merged_items.index, x=merged_items['item_price'], label='Revenue')
plt.title('Top 4 Most Popular Items and the Revenue Generated')

# Show the plot
plt.show()

# %% [markdown]
# Load the sleepstudy dataset from pydataset and read it's documentation. Use seaborn to create a line chart of all the individual subject's reaction times and a more prominant line showing the average change in reaction time.

# %%
# Load swiss dataset and read its documentation
data('sleepstudy', show_doc=True)
# Out:
# sleepstudy
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Reaction times in a sleep deprivation study
#
# ### Description
#
# The average reaction time per day for subjects in a sleep deprivation study.
# On day 0 the subjects had their normal amount of sleep. Starting that night
# they were restricted to 3 hours of sleep per night. The observations represent
# the average reaction time on a series of tests given each day to each subject.
#
# ### Format
#
# A data frame with 180 observations on the following 3 variables.
#
# `Reaction`
#
# Average reaction time (ms)
#
# `Days`
#
# Number of days of sleep deprivation
#
# `Subject`
#
# Subject number on which the observation was made.
#
# ### Details
#
# These data are from the study described in Belenky et al. (2003), for the
# sleep-deprived group and for the first 10 days of the study, up to the
# recovery period.
#
# ### References
#
# ...

# %% [markdown]
# seaborn.set_theme(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, rc=None)

# %%
# Load the sleepstudy dataset
sleepstudy = data('sleepstudy')

# Create line chart of all the individual subject's reaction times
sns.set_style("darkgrid")
plt.figure(figsize=(12,6))
sns.lineplot(x='Days', y='Reaction', data=sleepstudy, palette='tab10', hue='Subject')

# Create more prominent line showing the average change in reaction time
sns.lineplot(x='Days', y='Reaction', data=sleepstudy, color='black', ci=False, linewidth= 3, label='average')

# Set the plot title and axis labels
plt.title('Sleep Study Reaction Times')
plt.xlabel('Days')
plt.ylabel('Reaction Time')

# Show the plot
plt.show()
